# %% [markdown]
# ## GFIF papers

# %%
import pandas as pd

# %% [markdown]
# Make a GFIF query

# %%
q='(fc p or fc e) and aff antioquia u. and collection:published'
q=q.replace(' ','+')
df=pd.read_json(
    'https://inspirehep.net/search?p=find+{}&rg=250&of=recjson'.format(q))

# %%
df.shape
# Out:
# (195, 40)

# %% [markdown]
# explore a row for a published paper based on the previous query

# %%
df[df.title.astype(str).str.contains('Singlet-Doublet Dirac Dark Matter and Neutrino Masses')].reset_index(drop=True).to_dict()
# Out:
# {'FIXME_OAI': {0: {'id': 'oai:inspirehep.net:1741056',
#    'set': ['INSPIRE:HEP', 'ForSCOAP3']}},
#  'abbreviated_title': {0: nan},
#  'abstract': {0: [{'number': 'APS',
#     'summary': 'We examine an extension of the Standard Model that addresses the dark matter puzzle and generates Dirac neutrino masses through the radiative seesaw mechanism. The new field content includes a scalar field that plays an important role in setting the relic abundance of dark matter. We analyze the phenomenology in the light of direct, indirect, and collider searches of dark matter. In this framework, the dark matter candidate is a Dirac particle that is a mixture of new singlet-doublet fields with mass mχ10≲1.1\u2009\u2009TeV. We find that the allowed parameter space of this model is broader than the well-known Majorana dark matter scenario.'},
#    {'number': 'arXiv',
#     'summary': 'We examine an extension of the Standard Model that addresses the dark matter puzzle and generates Dirac neutrinos masses through the radiative seesaw mechanism. The new field content includes a scalar field that plays an important role in setting the relic abundance of dark matter. We analyze the phenomenology in the light of direct, indirect, and collider searches of dark matter. In this framework, the dark matter candidate is a Dirac particle that is a mixture of new singlet-doublet fields with mass $m_{\\chi_1^0}\\lesssim 1.1\\,\\text{TeV}$. We find that the allowed parameter space of this model is broader than the well-known Majorana dark matter scenario.'}]},
#  'accelerator_experiment': {0: nan},
#  'authors': {0: [{'affiliation': 'Antioquia U.',
#     'first_name': 'Diego',
#     'full_name': 'Restrepo, Diego',
#     'last_name': 'Restrepo'},
#    {'affiliation': 'Antioquia U.',
#     'first_name': 'Andrés',
#     'full_name': 'Rivera, Andrés',
#     'last_name': 'Rivera'},
#    {'affiliation': 'Loyola U., Chicago',
#     'first_name': 'Walter',
#     'full_name': 'Tangarife, Walter',
#     'last_name': 'Tangarife'}]},
#  'cataloguer_info': {0: {'creation_date': '2019-06-25'}},
#  'collection': {0: [{'primary': 'HEP'},
#    {'primary': 'Published'},
#    {'primary': 'Citeable'},
#    {'primary': 'CORE'}]},
#  'comment': {0: 'v3: Typos, new Refs. \\sigma_i real scalars'},
#  'corporate_name': {0: nan},
#  'coyright': {0: {'date': '2019',
#    'holder': 'authors',
#    'holder_contact': 'Article'}},
#  'creation_date': {0: '2019-06-25T05:01:50'},
#  'doi': {0: ['10.1103/PhysRevD.100.035029', '10.1103/PhysRevD.100.035029']},
#  'filenames': {0: ['scalar-SI',
#    'scalar-SI.png',
#    'fulltext',
#    'fulltext.xml',
#    'T-channel.png',
#    'T-channel',
#    'MSvsMD',
#    'MSvsMD.png',
#    'neutrino-GB.png',
#    'neutrino-GB',
#    'U-channel.png',
#    'U-channel',
#    'sv',
#    'sv.png',
#    '1906',
#    '1906.09685',
#    '1906.09685.pdf',
#    'SI.png',
#    'SI',
#    'scoap3-fulltext',
#    'scoap3-fulltext.pdf',
#    'vector-SI.png',
#    'vector-SI',
#    'S-channel',
#    'S-channel.png',
#    'SI-ratio.png',
#    'SI-ratio',
#    'SD.png',
#    'SD']},
#  'files': {0: [{'comment': None,
#     'description': '00003 SI independent DM-nucleon interactions: Scalar (left) and vector (right) portals.',
#     'eformat': '.png',
#     'full_name': 'scalar-SI.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819199/content.png;6',
#     'magic': ['PNG image data, 259 x 250, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 259 x 250, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'scalar-SI',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819199/content.png;6',
#     'size': 2276,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/scalar-SI.png',
#     'version': 6},
#    {'comment': None,
#     'description': None,
#     'eformat': '.xml',
#     'full_name': 'fulltext.xml',
#     'full_path': '/opt/cds-invenio/var/data/files/g195/3913114/content.xml;1',
#     'magic': ['XML 1.0 document text',
#      'application/xml; charset=utf-8',
#      'XML 1.0 document text',
#      'application/xml; charset=utf-8',
#      'application/xml'],
#     'name': 'fulltext',
#     'path': '/opt/cds-invenio/var/data/files/g195/3913114/content.xml;1',
#     'size': 259699,
#     'status': '',
#     'subformat': '',
#     'superformat': '.xml',
#     'type': 'APS',
#     'url': 'http://inspirehep.net/record/1741056/files/fulltext.xml',
#     'version': 1},
#    {'comment': None,
#     'description': '00010 Diagrams that contribute to the annihilation process $\\chi_1^0\\bar{\\chi}_1^0\\to h_2h_2$.',
#     'eformat': '.png',
#     'full_name': 'T-channel.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819200/content.png;6',
#     'magic': ['PNG image data, 249 x 219, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 249 x 219, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'T-channel',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819200/content.png;6',
#     'size': 2179,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/T-channel.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00002 $M_{\\Psi} - M_N$ plane for the scan done in this work. The blue dots give the correct relic abundance and reproduce the neutrino parameters. The pink-shaded region corresponds to overabundance or underabundance of DM. The green-shaded region is excluded by direct detection (DD) experiments.',
#     'eformat': '.png',
#     'full_name': 'MSvsMD.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819208/content.png;6',
#     'magic': ['PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'MSvsMD',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819208/content.png;6',
#     'size': 84413,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/MSvsMD.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00007 One-loop generation of Dirac neutrino masses. The arrows represent the flow of $U(1)_{B-L}$ charges.',
#     'eformat': '.png',
#     'full_name': 'neutrino-GB.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819202/content.png;6',
#     'magic': ['PNG image data, 433 x 226, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 433 x 226, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'neutrino-GB',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819202/content.png;6',
#     'size': 4717,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/neutrino-GB.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00004 Diagrams that contribute to the annihilation process $\\chi_1^0\\bar{\\chi}_1^0\\to h_2h_2$.',
#     'eformat': '.png',
#     'full_name': 'U-channel.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819206/content.png;6',
#     'magic': ['PNG image data, 283 x 208, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 283 x 208, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'U-channel',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819206/content.png;6',
#     'size': 2636,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/U-channel.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00008 Left: WIMP-neutron SD cross-sections and the current experimental constraints from XENON1T~\\cite{Aprile:2019dbj}, LUX~\\cite{Akerib:2017kat}, Ice-cube~\\cite{2013PhRvL.110m1302A}, and prospects as LZ~\\cite{Akerib:2018lyp} and DARWIN~\\cite{Aalbers:2016jon}. Right: Annihilation cross-section today. We also show the typical thermal value $\\langle\\sigma v\\rangle\\sim 3\\times 10^{-26}\\, \\text{cm}^3\\,\\text{s}^{-1}$   in the early universe and the experimental limit for DM annihilation into $b\\bar{b}$ in dwarf galaxies (dSphs)~\\cite{Ackermann:2015zua}.',
#     'eformat': '.png',
#     'full_name': 'sv.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819207/content.png;6',
#     'magic': ['PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'sv',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819207/content.png;6',
#     'size': 54127,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/sv.png',
#     'version': 6},
#    {'comment': None,
#     'description': 'Fulltext',
#     'eformat': '.pdf',
#     'full_name': '1906.09685.pdf',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819205/content.pdf;4',
#     'magic': ['PDF document, version 1.5',
#      'application/pdf; charset=binary',
#      'PDF document, version 1.5',
#      'application/pdf; charset=binary',
#      'application/pdf'],
#     'name': '1906.09685',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819205/content.pdf;4',
#     'size': 878914,
#     'status': '',
#     'subformat': '',
#     'superformat': '.pdf',
#     'type': 'arXiv',
#     'url': 'http://inspirehep.net/record/1741056/files/1906.09685.pdf',
#     'version': 4},
#    {'comment': None,
#     'description': '00001 Left: The SI cross-section (blue dots) and the current experimental constraints from XENON1T~\\cite{Aprile:2018dbl}, PandaX~\\cite{Cui:2017nnn}, and prospects from LZ~\\cite{Akerib:2018lyp} and DARWIN~\\cite{Aalbers:2016jon}. We also show the Neutrino Coherent Scattering (NCS)~\\cite{Cushman:2013zza, Billard:2013qya}. Right: The grey dots show the ratio between the scalar and vector SI cross-sections. The red stars are those models that are below the XENON1T limit',
#     'eformat': '.png',
#     'full_name': 'SI.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819203/content.png;6',
#     'magic': ['PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'SI',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819203/content.png;6',
#     'size': 86377,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/SI.png',
#     'version': 6},
#    {'comment': None,
#     'description': 'Article from SCOAP3',
#     'eformat': '.pdf',
#     'full_name': 'scoap3-fulltext.pdf',
#     'full_path': '/opt/cds-invenio/var/data/files/g195/3911917/content.pdf;1',
#     'magic': ['PDF document, version 1.4',
#      'application/pdf; charset=binary',
#      'PDF document, version 1.4',
#      'application/pdf; charset=binary',
#      'application/pdf'],
#     'name': 'scoap3-fulltext',
#     'path': '/opt/cds-invenio/var/data/files/g195/3911917/content.pdf;1',
#     'size': 1158553,
#     'status': '',
#     'subformat': '',
#     'superformat': '.pdf',
#     'type': 'SCOAP3',
#     'url': 'http://inspirehep.net/record/1741056/files/scoap3-fulltext.pdf',
#     'version': 1},
#    {'comment': None,
#     'description': '00005 SI independent DM-nucleon interactions: Scalar (left) and vector (right) portals.',
#     'eformat': '.png',
#     'full_name': 'vector-SI.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819204/content.png;6',
#     'magic': ['PNG image data, 259 x 250, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 259 x 250, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'vector-SI',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819204/content.png;6',
#     'size': 2630,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/vector-SI.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00009 Diagrams that contribute to the annihilation process $\\chi_1^0\\bar{\\chi}_1^0\\to h_2h_2$.',
#     'eformat': '.png',
#     'full_name': 'S-channel.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819201/content.png;6',
#     'magic': ['PNG image data, 247 x 208, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 247 x 208, 8-bit colormap, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'S-channel',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819201/content.png;6',
#     'size': 2456,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/S-channel.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00006 Left: The SI cross-section (blue dots) and the current experimental constraints from XENON1T~\\cite{Aprile:2018dbl}, PandaX~\\cite{Cui:2017nnn}, and prospects from LZ~\\cite{Akerib:2018lyp} and DARWIN~\\cite{Aalbers:2016jon}. We also show the Neutrino Coherent Scattering (NCS)~\\cite{Cushman:2013zza, Billard:2013qya}. Right: The grey dots show the ratio between the scalar and vector SI cross-sections. The red stars are those models that are below the XENON1T limit',
#     'eformat': '.png',
#     'full_name': 'SI-ratio.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819209/content.png;6',
#     'magic': ['PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'SI-ratio',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819209/content.png;6',
#     'size': 109625,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/SI-ratio.png',
#     'version': 6},
#    {'comment': None,
#     'description': '00000 Left: WIMP-neutron SD cross-sections and the current experimental constraints from XENON1T~\\cite{Aprile:2019dbj}, LUX~\\cite{Akerib:2017kat}, Ice-cube~\\cite{2013PhRvL.110m1302A}, and prospects as LZ~\\cite{Akerib:2018lyp} and DARWIN~\\cite{Aalbers:2016jon}. Right: Annihilation cross-section today. We also show the typical thermal value $\\langle\\sigma v\\rangle\\sim 3\\times 10^{-26}\\, \\text{cm}^3\\,\\text{s}^{-1}$   in the early universe and the experimental limit for DM annihilation into $b\\bar{b}$ in dwarf galaxies (dSphs)~\\cite{Ackermann:2015zua}.',
#     'eformat': '.png',
#     'full_name': 'SD.png',
#     'full_path': '/opt/cds-invenio/var/data/files/g190/3819210/content.png;6',
#     'magic': ['PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'PNG image data, 576 x 432, 8-bit/color RGBA, non-interlaced',
#      'image/png; charset=binary',
#      'image/png'],
#     'name': 'SD',
#     'path': '/opt/cds-invenio/var/data/files/g190/3819210/content.png;6',
#     'size': 74831,
#     'status': '',
#     'subformat': '',
#     'superformat': '.png',
#     'type': 'Plot',
#     'url': 'http://inspirehep.net/record/1741056/files/SD.png',
#     'version': 6}]},
#  'filetypes': {0: ['png',
#    'xml',
#    'png',
#    'png',
#    'png',
#    'png',
#    'png',
#    'pdf',
#    'png',
#    'pdf',
#    'png',
#    'png',
#    'png',
#    'png']},
#  'imprint': {0: {'date': '2019-08-29'}},
#  'keywords': {0: [{'institute': 'publisher',
#     'term': 'Beyond the standard model'}]},
#  'license': {0: [{'license': 'arXiv nonexclusive-distrib 1.0',
#     'material': 'preprint',
#     'url': 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/'},
#    {'imposing': 'APS',
#     'license': 'Creative Commons Attribution 4.0 International',
#     'url': 'https://creativecommons.org/licenses/by/4.0/'}]},
#  'number_of_authors': {0: 3},
#  'number_of_citations': {0: 4},
#  'number_of_comments': {0: 0},
#  'number_of_reviews': {0: 0},
#  'oai': {0: nan},
#  'other_report_number': {0: nan},
#  'persistent_identifiers_keys': {0: ['recid', 'system_control_number', 'doi']},
#  'physical_description': {0: {'pagination': '11'}},
#  'prepublication': {0: {'date': '2019-06-23'}},
#  'primary_report_number': {0: 'arXiv:1906.09685'},
#  'publication_info': {0: {'pagination': '035029',
#    'reference': 'Phys. Rev. D 100, 035029 (2019)',
#    'title': 'Phys.Rev.',
#    'volume': 'D100',
#    'year': '2019'}},
#  'recid': {0: 1741056},
#  'reference': {0: [{'authors': 'Zwicky, F.',
#     'doi': 'doi:10.1086/143864',
#     'order_number': '1',
#     'title': 'Astrophys.J.,86,217',
#     'year': '1937'},
#    {'authors': ['Gorenstein, P.', 'Tucker, W.'],
#     'doi': 'doi:10.1155/2014/878203',
#     'order_number': '2',
#     'title': 'Adv.High Energy Phys.,2014,1',
#     'year': '2014'},
#    {'authors': ['Rubin, V.C.', 'Ford, W.K.', 'Jr.'],
#     'doi': 'doi:10.1086/150317',
#     'order_number': '3',
#     'title': 'Astrophys.J.,159,379',
#     'year': '1970'},
#    {'authors': ['Rubin, V.C.', 'Thonnard, N.', 'Ford, W.K.', 'Jr.'],
#     'doi': 'doi:10.1086/158003',
#     'order_number': '4',
#     'title': 'Astrophys.J.,238,471',
#     'year': '1980'},
#    {'authors': 'Aghanim, N.',
#     'order_number': '5',
#     'report_number': 'arXiv:1807.06209'},
#    {'authors': ['Clowe, D.',
#      'Bradac, M.',
#      'Gonzalez, A.H.',
#      'Markevitch, M.',
#      'Randall, S.W.',
#      'Jones, C.',
#      'Zaritsky, D.'],
#     'doi': 'doi:10.1086/508162',
#     'order_number': '6',
#     'title': 'Astrophys.J.,648,L109',
#     'year': '2006'},
#    {'authors': 'Refregier, A.',
#     'doi': 'doi:10.1146/annurev.astro.41.111302.102207',
#     'order_number': '7',
#     'title': 'Ann.Rev.Astron.Astrophys.,41,645',
#     'year': '2003'},
#    {'authors': ['Tyson, J.A.', 'Kochanski, G.P.', "Dell'Antonio, I.P."],
#     'doi': 'doi:10.1086/311314',
#     'order_number': '8',
#     'title': 'Astrophys.J.,498,L107',
#     'year': '1998'},
#    {'authors': ['Frenk, C.S.', 'White, S.D.M.'],
#     'doi': 'doi:10.1002/andp.201200212',
#     'order_number': '9',
#     'title': 'Ann.Phys.(Amsterdam),524,507',
#     'year': '2012'},
#    {'authors': ['de Salas, P.F.',
#      'Forero, D.V.',
#      'Ternes, C.A.',
#      'Tortola, M.',
#      'Valle, J.W.F.'],
#     'doi': 'doi:10.1016/j.physletb.2018.06.019',
#     'order_number': '10',
#     'title': 'Phys.Lett.,B782,633',
#     'year': '2018'},
#    {'authors': 'Yaguna, C.E.',
#     'doi': 'doi:10.1103/PhysRevD.92.115002',
#     'order_number': '11',
#     'title': 'Phys.Rev.,D92,115002',
#     'year': '2015'},
#    {'authors': ['Arkani-Hamed, N.', 'Dimopoulos, S.', 'Kachru, S.'],
#     'order_number': '12',
#     'report_number': 'hep-th/0501082'},
#    {'authors': ['Mahbubani, R.', 'Senatore, L.'],
#     'doi': 'doi:10.1103/PhysRevD.73.043510',
#     'order_number': '13',
#     'title': 'Phys.Rev.,D73,043510',
#     'year': '2006'},
#    {'authors': "D'Eramo, F.",
#     'doi': 'doi:10.1103/PhysRevD.76.083522',
#     'order_number': '14',
#     'title': 'Phys.Rev.,D76,083522',
#     'year': '2007'},
#    {'authors': ['Enberg, R.',
#      'Fox, P.',
#      'Hall, L.',
#      'Papaioannou, A.',
#      'Papucci, M.'],
#     'doi': 'doi:10.1088/1126-6708/2007/11/014',
#     'order_number': '15',
#     'title': 'JHEP,0711,014',
#     'year': '2007'},
#    {'authors': ['Cohen, T.', 'Kearney, J.', 'Pierce, A.', 'Tucker-Smith, D.'],
#     'doi': 'doi:10.1103/PhysRevD.85.075003',
#     'order_number': '16',
#     'title': 'Phys.Rev.,D85,075003',
#     'year': '2012'},
#    {'authors': ['Cheung, C.', 'Sanford, D.'],
#     'doi': 'doi:10.1088/1475-7516/2014/02/011',
#     'order_number': '17',
#     'title': 'JCAP,1402,011',
#     'year': '2020'},
#    {'authors': ['Abe, T.', 'Kitano, R.', 'Sato, R.'],
#     'doi': 'doi:10.1103/PhysRevD.91.095004',
#     'order_number': '18',
#     'title': 'Phys.Rev.,D91,095004',
#     'year': '2015'},
#    {'authors': ['Restrepo, D.',
#      'Rivera, A.',
#      'Sánchez-Peláez, M.',
#      'Zapata, O.',
#      'Tangarife, W.'],
#     'doi': 'doi:10.1103/PhysRevD.92.013005',
#     'order_number': '19',
#     'title': 'Phys.Rev.,D92,013005',
#     'year': '2015'},
#    {'authors': ['Calibbi, L.', 'Mariotti, A.', 'Tziveloglou, P.'],
#     'doi': 'doi:10.1007/JHEP10(2015)116',
#     'order_number': '20',
#     'title': 'JHEP,1510,116',
#     'year': '2015'},
#    {'authors': ['Horiuchi, S.',
#      'Macias, O.',
#      'Restrepo, D.',
#      'Rivera, A.',
#      'Zapata, O.',
#      'Silverwood, H.'],
#     'doi': 'doi:10.1088/1475-7516/2016/03/048',
#     'order_number': '21',
#     'title': 'JCAP,1603,048',
#     'year': '2020'},
#    {'authors': ['Bhattacharya, S.', 'Ghosh, P.', 'Sahu, N.'],
#     'doi': 'doi:10.1007/JHEP02(2019)059',
#     'order_number': '22',
#     'title': 'JHEP,1902,059',
#     'year': '2019'},
#    {'authors': ['Bhattacharya, S.', 'Ghosh, P.', 'Sahoo, N.', 'Sahu, N.'],
#     'doi': 'doi:10.3389/fphy.2019.00080',
#     'order_number': '23',
#     'title': 'Front.Phys.,7,80',
#     'year': '2019'},
#    {'authors': 'Mount, B.J.',
#     'order_number': '24',
#     'report_number': 'arXiv:1703.09144'},
#    {'authors': 'Ma, E.',
#     'doi': 'doi:10.1103/PhysRevD.73.077301',
#     'order_number': '25',
#     'title': 'Phys.Rev.,D73,077301',
#     'year': '2006'},
#    {'authors': ['Chuliá, S. Centelles',
#      'Ma, E.',
#      'Srivastava, R.',
#      'Valle, J.W.F.'],
#     'doi': 'doi:10.1016/j.physletb.2017.01.070',
#     'order_number': '26',
#     'title': 'Phys.Lett.,B767,209',
#     'year': '2017'},
#    {'authors': ['Chuliá, S. Centelles', 'Srivastava, R.', 'Valle, J.W.F.'],
#     'doi': 'doi:10.1016/j.physletb.2018.03.046',
#     'order_number': '27',
#     'title': 'Phys.Lett.,B781,122',
#     'year': '2018'},
#    {'authors': ['Calle, J.', 'Restrepo, D.', 'Yaguna, C.E.', 'Zapata, O.'],
#     'doi': 'doi:10.1103/PhysRevD.99.075008',
#     'order_number': '28',
#     'title': 'Phys.Rev.,D99,075008',
#     'year': '2019'},
#    {'authors': 'Kannike, K.',
#     'doi': 'doi:10.1140/epjc/s10052-012-2093-z',
#     'order_number': '29',
#     'title': 'Eur.Phys.J.,C72,2093',
#     'year': '2012'},
#    {'authors': ['Falkowski, A.', 'Gross, C.', 'Lebedev, O.'],
#     'doi': 'doi:10.1007/JHEP05(2015)057',
#     'order_number': '30',
#     'title': 'JHEP,1505,057',
#     'year': '2015'},
#    {'authors': 'Aaboud, M.',
#     'doi': 'doi:10.1103/PhysRevD.98.052005',
#     'order_number': '31',
#     'title': 'Phys.Rev.,D98,052005',
#     'year': '2018'},
#    {'misc': 'Report No',
#     'order_number': '32',
#     'report_number': 'ATLAS-CONF-2018-028',
#     'year': '2018'},
#    {'authors': 'Sirunyan, A.M.',
#     'doi': 'doi:10.1007/JHEP11(2018)185',
#     'order_number': '33',
#     'title': 'JHEP,1811,185',
#     'year': '2018'},
#    {'authors': 'Khachatryan, V.',
#     'doi': 'doi:10.1007/JHEP10(2015)144',
#     'order_number': '34',
#     'title': 'JHEP,1510,144',
#     'year': '2015'},
#    {'authors': ['Restrepo, D.', 'Zapata, O.', 'Yaguna, C.E.'],
#     'doi': 'doi:10.1007/JHEP11(2013)011',
#     'order_number': '35',
#     'title': 'JHEP,1311,011',
#     'year': '2013'},
#    {'authors': ['Yao, C.-Y.', 'Ding, G.-J.'],
#     'doi': 'doi:10.1103/PhysRevD.97.095042',
#     'order_number': '36',
#     'title': 'Phys.Rev.,D97,095042',
#     'year': '2018'},
#    {'authors': ['Kanemura, S.', 'Nabeshima, T.', 'Sugiyama, H.'],
#     'doi': 'doi:10.1016/j.physletb.2011.07.047',
#     'order_number': '37',
#     'title': 'Phys.Lett.,B703,66',
#     'year': '2011'},
#    {'authors': ['Maki, Z.', 'Nakagawa, M.', 'Sakata, S.'],
#     'doi': 'doi:10.1143/PTP.28.870',
#     'order_number': '38',
#     'title': 'Prog.Theor.Phys.,28,870',
#     'year': '1962'},
#    {'authors': ['Kolb, E.W.', 'Turner, M.S.'],
#     'order_number': '39',
#     'title': 'Front.Phys.,69,1',
#     'year': '1990'},
#    {'authors': ['Srednicki, M.', 'Watkins, R.', 'Olive, K.A.'],
#     'doi': 'doi:10.1016/0550-3213(88)90099-5',
#     'order_number': '40',
#     'title': 'Nucl.Phys.,B310,693',
#     'year': '1988'},
#    {'authors': ['Belanger, G.', 'Boudjema, F.', 'Pukhov, A.', 'Semenov, A.'],
#     'doi': 'doi:10.1016/j.cpc.2008.11.019',
#     'order_number': '41',
#     'title': 'Comput.Phys.Commun.,180,747',
#     'year': '2009'},
#    {'authors': ['Alarcon, J.M.', 'Camalich, J. Martin', 'Oller, J.A.'],
#     'doi': 'doi:10.1103/PhysRevD.85.051503',
#     'order_number': '42',
#     'title': 'Phys.Rev.,D85,051503',
#     'year': '2012'},
#    {'authors': ['Alarcon, J.M.',
#      'Geng, L.S.',
#      'Camalich, J. Martin',
#      'Oller, J.A.'],
#     'doi': 'doi:10.1016/j.physletb.2014.01.065',
#     'order_number': '43',
#     'title': 'Phys.Lett.,B730,342',
#     'year': '2014'},
#    {'authors': ['Lewin, J.D.', 'Smith, P.F.'],
#     'doi': 'doi:10.1016/S0927-6505(96)00047-3',
#     'order_number': '44',
#     'title': 'Astropart.Phys.,6,87',
#     'year': '1996'},
#    {'authors': 'Aprile, E.',
#     'doi': 'doi:10.1103/PhysRevLett.122.141301',
#     'order_number': '45',
#     'title': 'Phys.Rev.Lett.,122,141301',
#     'year': '2019'},
#    {'authors': 'Akerib, D.S.',
#     'doi': 'doi:10.1103/PhysRevLett.118.251302',
#     'order_number': '46',
#     'title': 'Phys.Rev.Lett.,118,251302',
#     'year': '2017'},
#    {'authors': 'Staub, F.',
#     'order_number': '47',
#     'report_number': 'arXiv:0806.0538'},
#    {'authors': 'Staub, F.',
#     'doi': 'doi:10.1016/j.cpc.2010.01.011',
#     'order_number': '48',
#     'title': 'Comput.Phys.Commun.,181,1077',
#     'year': '2010'},
#    {'authors': 'Staub, F.',
#     'doi': 'doi:10.1016/j.cpc.2010.11.030',
#     'order_number': '49',
#     'title': 'Comput.Phys.Commun.,182,808',
#     'year': '2011'},
#    {'authors': 'Staub, F.',
#     'doi': 'doi:10.1016/j.cpc.2013.02.019',
#     'order_number': '50',
#     'title': 'Comput.Phys.Commun.,184,1792',
#     'year': '2013'},
#    {'authors': 'Staub, F.',
#     'doi': 'doi:10.1016/j.cpc.2014.02.018',
#     'order_number': '51',
#     'title': 'Comput.Phys.Commun.,185,1773',
#     'year': '2014'},
#    {'authors': 'Porod, W.',
#     'doi': 'doi:10.1016/S0010-4655(03)00222-4',
#     'order_number': '52',
#     'title': 'Comput.Phys.Commun.,153,275',
#     'year': '2003'},
#    {'authors': ['Porod, W.', 'Staub, F.'],
#     'doi': 'doi:10.1016/j.cpc.2012.05.021',
#     'order_number': '53',
#     'title': 'Comput.Phys.Commun.,183,2458',
#     'year': '2012'},
#    {'authors': ['Belanger, G.', 'Boudjema, F.', 'Pukhov, A.', 'Semenov, A.'],
#     'doi': 'doi:10.1016/j.cpc.2006.11.008',
#     'order_number': '54',
#     'title': 'Comput.Phys.Commun.,176,367',
#     'year': '2007'},
#    {'authors': ['Griest, K.', 'Seckel, D.'],
#     'doi': 'doi:10.1103/PhysRevD.43.3191',
#     'order_number': '55',
#     'title': 'Phys.Rev.,D43,3191',
#     'year': '1991'},
#    {'authors': 'Aprile, E.',
#     'doi': 'doi:10.1103/PhysRevLett.121.111302',
#     'order_number': '56',
#     'title': 'Phys.Rev.Lett.,121,111302',
#     'year': '2018'},
#    {'authors': 'Cui, X.',
#     'doi': 'doi:10.1103/PhysRevLett.119.181302',
#     'order_number': '57',
#     'title': 'Phys.Rev.Lett.,119,181302',
#     'year': '2017'},
#    {'authors': 'Akerib, D.S.',
#     'order_number': '58',
#     'report_number': 'arXiv:1802.06039'},
#    {'authors': 'Aalbers, J.',
#     'doi': 'doi:10.1088/1475-7516/2016/11/017',
#     'order_number': '59',
#     'title': 'JCAP,1611,017',
#     'year': '2020'},
#    {'authors': 'Cushman, P.',
#     'order_number': '60',
#     'url': 'http://www.slac.stanford.edu/econf/C1307292',
#     'year': '2013'},
#    {'authors': ['Billard, J.', 'Strigari, L.', 'Figueroa-Feliciano, E.'],
#     'doi': 'doi:10.1103/PhysRevD.89.023524',
#     'order_number': '61',
#     'title': 'Phys.Rev.,D89,023524',
#     'year': '2014'},
#    {'authors': ['Aartsen, M.G.',
#      'Abbasi, R.',
#      'Abdou, Y.',
#      'Ackermann, M.',
#      'Adams, J.',
#      'Aguilar, J.A.',
#      'Ahlers, M.',
#      'Altmann, D.',
#      'Auffenberg, J.',
#      'Bai, X.'],
#     'doi': 'doi:10.1103/PhysRevLett.110.131302',
#     'order_number': '62',
#     'title': 'Phys.Rev.Lett.,110,131302',
#     'year': '2013'},
#    {'authors': 'Ackermann, M.',
#     'doi': 'doi:10.1103/PhysRevLett.115.231301',
#     'order_number': '63',
#     'title': 'Phys.Rev.Lett.,115,231301',
#     'year': '2015'},
#    {'misc': 'Report No',
#     'order_number': '64',
#     'report_number': 'ATLAS-CONF-2019-008',
#     'year': '2019'}]},
#  'source_of_acquisition': {0: {'accession_number': '1801894',
#    'date': '2019-09-05T02:35:34.664634',
#    'source_of_acquisition': 'arXiv'}},
#  'subject': {0: [{'source': 'INSPIRE', 'term': 'Phenomenology-HEP'},
#    {'source': 'INSPIRE', 'term': 'Phenomenology-HEP'},
#    {'source': 'arXiv', 'term': 'hep-ph'}]},
#  'system_control_number': {0: [{'institute': 'INSPIRETeX',
#     'value': 'Restrepo:2019soi'},
#    {'institute': 'arXiv', 'value': 'oai:arXiv.org:1906.09685'},
#    {'canceled': 'DA19-kp28h', 'institute': 'DESY'}]},
#  'system_number': {0: nan},
#  'thesaurus_terms': {0: [{'term': 'dark matter: relic density'},
#    {'term': 'dark matter: singlet'},
#    {'term': 'dark matter: direct detection'},
#    {'term': 'dark matter: mass'},
#    {'term': 'scalar particle: doublet'},
#    {'term': 'scalar particle: new particle'},
#    {'term': 'neutrino: Dirac: mass'},
#    {'term': 'particle: Dirac'},
#    {'term': 'field theory: scalar'},
#    {'term': 'seesaw model'},
#    {'term': 'Majorana'},
#    {'term': 'new physics'}]},
#  'title': {0: {'title': 'Singlet-Doublet Dirac Dark Matter and Neutrino Masses'}},
#  'title_additional': {0: nan},
#  'url': {0: nan},
#  'version_id': {0: '2019-09-10T14:35:49'}}

# %% [markdown]
# Filter published papers (query already filtered!)

# %%
dfp=df[~df['publication_info'].isna()].reset_index(drop=True)

# %% [markdown]
# Get the Journal info from crossref api

# %%
journal={}

# %%
import time
def get_journal_info(row,journal=journal,abrv_journal='publication_info'
                                        ,abrv_journal_title='title'
                                        ,doi='doi'
                                        ,container_title='container_title'
                                        ,issn='ISSN'):
    
    try:
        j=row.get(abrv_journal).get(abrv_journal_title)
    except:
        j=None
    if j and not journal.get(j):
        journal.update( {j:{}} )
    
    if not journal.get(j) and row.get(doi):
        strdoi=row.get(doi)
        try:
            di=pd.read_json( 'https://api.crossref.org/works/{}'.format( strdoi  ) )
        except:
            di=pd.DataFrame()
        if j in journal and not journal.get(j).get(container_title):
            try:
                ct=di.loc['container-title'][0][0]
                journal[j].update({container_title:ct})

            except:
                pass
        if j in journal and not journal.get(j).get(issn):
            try:
                gis=di.loc['ISSN'].get('message')[0]
                journal[j].update({issn:gis})
            except:
                pass
        #Get a new journal crossref metadata here

        time.sleep(1)
        return di

# %%
di=dfp.apply(get_journal_info,axis=1)

# %%
journal
# Out:
# {'Eur.Phys.J.': {'ISSN': '1434-6044',
#   'container_title': 'The European Physical Journal C'},
#  'Europhys.Lett.': {'ISSN': '0295-5075',
#   'container_title': 'Europhysics Letters (EPL)'},
#  'Int.J.Mod.Phys.': {'ISSN': '0217-751X',
#   'container_title': 'International Journal of Modern Physics A'},
#  'J.Phys.': {'ISSN': '0954-3899',
#   'container_title': 'Journal of Physics G: Nuclear and Particle Physics'},
#  'JCAP': {'ISSN': '1475-7516',
#   'container_title': 'Journal of Cosmology and Astroparticle Physics'},
#  'JHEP': {'ISSN': '1029-8479',
#   'container_title': 'Journal of High Energy Physics'},
#  'JINST': {'ISSN': '1748-0221',
#   'container_title': 'Journal of Instrumentation'},
#  'Mod.Phys.Lett.': {'ISSN': '0217-7323',
#   'container_title': 'Modern Physics Letters A'},
#  'Nucl.Phys.': {'ISSN': '0550-3213', 'container_title': 'Nuclear Physics B'},
#  'Phys.Lett.': {'ISSN': '0370-2693', 'container_title': 'Physics Letters B'},
#  'Phys.Rept.': {'ISSN': '0370-1573', 'container_title': 'Physics Reports'},
#  'Phys.Rev.': {'ISSN': '2470-0010', 'container_title': 'Physical Review D'},
#  'Phys.Rev.Lett.': {'ISSN': '0031-9007',
#   'container_title': 'Physical Review Letters'},
#  'Rev.Mex.Fis.': {},
#  'Z.Phys.': {'ISSN': '0170-9739',
#   'container_title': 'Zeitschrift f�r Physik C Particles and Fields'}}

# %% [markdown]
# Normalize data

# %%
dfp['title_TeX']=dfp['title'].apply(
                lambda d: d[0] if isinstance(d,list) else d
            ).apply(
                lambda d: d.get('title') if isinstance(d,dict) else d)

# %% [markdown]
# Add Journal metadata

# %%
dfp['Year']=dfp['publication_info'].apply(
    lambda d: d.get('year') if isinstance(d,dict) else None).apply(
    lambda y: int(y) if isinstance(y,str) else 0)

dfp['Journal_name']=dfp['publication_info'].apply(lambda d: journal.get( 
                                        d.get('title') ).get('container_title') 
                                        if isinstance(d,dict) 
                                        else None)
dfp['ISSN']=dfp['publication_info'].apply(lambda d: journal.get( 
                                        d.get('title') ).get('ISSN') 
                                        if isinstance(d,dict) 
                                        else None)

# %%
dfp['udea_authors']=dfp['authors'].apply(lambda l: [ #loop for each author in the list
        '{} {}'.format(d.get('first_name'), d.get('last_name')) #Extract full name 
         for d in l 
           if str(d.get('affiliation')).find('Antioquia U.')>-1 #For UdeA authors
                               ])
dfp['first_udea_author']=dfp['udea_authors'].str[0]

# %%
sost=dfp[['title_TeX','Journal_name','first_udea_author','Year','ISSN','doi']]

# %%
sost[sost.Year>2017]
# Out:
#                                             title_TeX  \
# 0   Observation of the $\Lambda_\mathrm{b}^0 \to$ ...
# 1   Search for supersymmetry with a compressed mas...
# 2   Dirac neutrino mass generation from Majorana m...
# 3   Search for long-lived particles using delayed ...
# 4   Evidence for WW production from double-parton ...
# 5   Measurements of differential Z boson productio...
# 6   Search for low mass vector resonances decaying...
# 7   Searches for physics beyond the standard model...
# 8   Search for a charged Higgs boson decaying into...
# 9   Search for supersymmetry using Higgs boson to ...
# 10  Search for production of four top quarks in fi...
# 11  Search for supersymmetry in proton-proton coll...
# 12  Search for dark photons in decays of Higgs bos...
# 13  Measurement of the average very forward energy...
# 14  Search for anomalous triple gauge couplings in...
# 15  Charged current $b \to c \tau \bar{\nu}_\tau$ ...
# 16  Search for light pseudoscalar boson pairs prod...
# 17  Search for physics beyond the standard model i...
# 18  Study of the $ {\mathrm{B}}^{+}\to \mathrm{J}/...
# 19  Measurement of the top quark polarization and ...
# 20  Search for MSSM Higgs bosons decaying to $\mu^...
# 21  Measurement of the top quark Yukawa coupling f...
# 22  Combined search for supersymmetry with photons...
# 23  Search for pair production of vectorlike quark...
# 24  Singlet-Doublet Dirac Dark Matter and Neutrino...
# 25  Search for long-lived particles using nonpromp...
# 26  Search for the production of four top quarks i...
# 27  Search for supersymmetry with a compressed mas...
# 28  Search for vector-like leptons in multilepton ...
# 29  Search for Higgs and Z boson decays to J/$\psi...
# 30  Search for low-mass quark-antiquark resonances...
# 31  Search for anomalous electroweak production of...
# 32  Search for a light charged Higgs boson decayin...
# 33  Search for the production of W$^\pm$W$^\pm$W$^...
# 34  Search for supersymmetry in final states with ...
# 35  Measurement of electroweak production of a W b...
# 36  Observation of Two Excited B$^+_\mathrm{c}$ St...
# 37  Search for $W$ boson decays to three charged p...
# 38  One-loop Dirac neutrino mass and mixed axion-W...
# 39  Observation of Single Top Quark Production in ...
# 40       Minimal radiative Dirac neutrino mass models
# 41  Mono-$\tau$ Signatures at the LHC Constrain Ex...
# 42  Search for invisible decays of a Higgs boson p...
# 43  Phenomenology of doublet-triplet fermionic dar...
# 44  Charged lepton flavor violation and electric d...
# 45  Two-component dark matter and a massless neutr...
# 46  Novel Way to Search for Light Dark Matter in L...
# 47    Bound-state dark matter with Majorana neutrinos
# 48  Probing a simplified, $W^{\prime}$ model of $R...
# 49  Bound-state dark matter and Dirac neutrino masses
# 50  Simple no-scale model of modulus fixing and in...
# 51  Resonant production of dark photons in positro...
# 52  Dark photon production through positron annihi...
# 53  Electroweak couplings and LHC constraints on a...
# 54     Vector Boson Fusion in the Inert Doublet Model
# 55  Measuring the mass, width, and couplings of se...
# 56  Expanding the Reach of Heavy Neutrino Searches...
# 57  Search for natural supersymmetry in events wit...
# 59  Anomalous leptonic U(1) symmetry: Syndetic ori...
# 60  Suppression of Excited $\Upsilon$ States Relat...
#
#                                  Journal_name        first_udea_author  Year  \
# 0                           Physics Letters B    Jhovanny Mejia Guisao  2020
# 1                     Physical Review Letters    Jhovanny Mejia Guisao  2020
# 2                           Physical Review D             Julian Calle  2020
# 3                           Physical Review D    Jhovanny Mejia Guisao  2019
# 4             The European Physical Journal C    Jhovanny Mejia Guisao  2020
# 5              Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 6                           Physical Review D    Jhovanny Mejia Guisao  2019
# 7             The European Physical Journal C    Jhovanny Mejia Guisao  2020
# 8              Journal of High Energy Physics    Jhovanny Mejia Guisao  2020
# 9              Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 10            The European Physical Journal C    Jhovanny Mejia Guisao  2020
# 11             Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 12             Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 13            The European Physical Journal C  José David Ruiz Alvarez  2019
# 14             Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 15                          Physical Review D            John D. Gómez  2019
# 16                          Physics Letters B  José David Ruiz Alvarez  2020
# 17                    Physical Review Letters    Jhovanny Mejia Guisao  2019
# 18             Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 19                          Physical Review D  José David Ruiz Alvarez  2019
# 20                          Physics Letters B  José David Ruiz Alvarez  2019
# 21                          Physical Review D    Jhovanny Mejia Guisao  2019
# 22                          Physics Letters B    Jhovanny Mejia Guisao  2020
# 23                          Physical Review D    Jhovanny Mejia Guisao  2019
# 24                          Physical Review D           Diego Restrepo  2019
# 25                          Physics Letters B    Jhovanny Mejia Guisao  2019
# 26             Journal of High Energy Physics    Jhovanny Mejia Guisao  2019
# 27             Journal of High Energy Physics  José David Ruiz Alvarez  2019
# 28                          Physical Review D    Jhovanny Mejia Guisao  2019
# 29                          Physics Letters B    Jhovanny Mejia Guisao  2019
# 30                    Physical Review Letters  José David Ruiz Alvarez  2019
# 31                          Physics Letters B  José David Ruiz Alvarez  2019
# 32                    Physical Review Letters  José David Ruiz Alvarez  2019
# 33                          Physical Review D    Jhovanny Mejia Guisao  2019
# 34             Journal of High Energy Physics  José David Ruiz Alvarez  2019
# 35            The European Physical Journal C  José David Ruiz Alvarez  2020
# 36                    Physical Review Letters    Jhovanny Mejia Guisao  2019
# 37                    Physical Review Letters  José David Ruiz Alvarez  2019
# 38                          Physical Review D   Cristian D.R. Carvajal  2019
# 39                    Physical Review Letters  José David Ruiz Alvarez  2019
# 40                          Physical Review D             Julian Calle  2019
# 41                    Physical Review Letters  José David Ruiz-Álvarez  2019
# 42                          Physics Letters B  José David Ruiz Alvarez  2019
# 43                          Physical Review D          Amalia Betancur  2018
# 44             Journal of High Energy Physics        Alexandra Gaviria  2018
# 45                          Physical Review D           Diego Restrepo  2019
# 46                    Physical Review Letters         C.D. R. Carvajal  2018
# 47                          Physics Letters B              D. Restrepo  2019
# 48                          Physical Review D             Julian Calle  2018
# 49                          Physical Review D              D. Restrepo  2018
# 50                          Physical Review D      Antonio Enea Romano  2018
# 51                          Physical Review D   Cristian D.R. Carvajal  2018
# 52                          Physical Review D         C.D. R. Carvajal  2018
# 53  International Journal of Modern Physics A         William A. Ponce  2018
# 54                          Physical Review D        Guillermo Palacio  2018
# 55                          Physical Review D          Amalia Betancur  2019
# 56                          Physics Letters B           Diego Restrepo  2018
# 57             Journal of High Energy Physics  José David Ruiz Alvarez  2018
# 59                   Modern Physics Letters A           Diego Restrepo  2018
# 60                    Physical Review Letters  José David Ruiz Alvarez  2018
#
#          ISSN                                                doi
# 0   0370-2693                     10.1016/j.physletb.2020.135203
# 1   0031-9007                     10.1103/PhysRevLett.124.041803
# 2   2470-0010                        10.1103/PhysRevD.101.035004
# 3   2470-0010                        10.1103/PhysRevD.100.112003
# 4   1434-6044                     10.1140/epjc/s10052-019-7541-6
# 5   1029-8479                            10.1007/JHEP12(2019)061
# 6   2470-0010                        10.1103/PhysRevD.100.112007
# 7   1434-6044                     10.1140/epjc/s10052-019-7493-x
# 8   1029-8479                            10.1007/JHEP01(2020)096
# 9   1029-8479                            10.1007/JHEP11(2019)109
# 10  1434-6044  [10.1140/epjc/s10052-019-7593-7, 10.1140/epjc/...
# 11  1029-8479  [10.1007/JHEP10(2019)244, 10.1007/JHEP10(2019)...
# 12  1029-8479  [10.1007/JHEP10(2019)139, 10.1007/JHEP10(2019)...
# 13  1434-6044  [10.1140/epjc/s10052-019-7402-3, 10.1140/epjc/...
# 14  1029-8479                            10.1007/JHEP12(2019)062
# 15  2470-0010                        10.1103/PhysRevD.100.093003
# 16  0370-2693  [10.1016/j.physletb.2019.135087, 10.1016/j.phy...
# 17  0031-9007  [10.1103/PhysRevLett.123.241801, 10.1103/PhysR...
# 18  1029-8479                            10.1007/JHEP12(2019)100
# 19  2470-0010                        10.1103/PhysRevD.100.072002
# 20  0370-2693                     10.1016/j.physletb.2019.134992
# 21  2470-0010  [10.1103/PhysRevD.100.072007, 10.1103/PhysRevD...
# 22  0370-2693                     10.1016/j.physletb.2019.135183
# 23  2470-0010                        10.1103/PhysRevD.100.072001
# 24  2470-0010  [10.1103/PhysRevD.100.035029, 10.1103/PhysRevD...
# 25  0370-2693                     10.1016/j.physletb.2019.134876
# 26  1029-8479                            10.1007/JHEP11(2019)082
# 27  1029-8479  [10.1007/JHEP08(2019)150, 10.1007/JHEP08(2019)...
# 28  2470-0010                        10.1103/PhysRevD.100.052003
# 29  0370-2693                     10.1016/j.physletb.2019.134811
# 30  0031-9007                     10.1103/PhysRevLett.123.231803
# 31  0370-2693                     10.1016/j.physletb.2019.134985
# 32  0031-9007                     10.1103/PhysRevLett.123.131802
# 33  2470-0010  [10.1103/PhysRevD.100.012004, 10.1103/PhysRevD...
# 34  1029-8479                            10.1007/JHEP06(2019)143
# 35  1434-6044                     10.1140/epjc/s10052-019-7585-7
# 36  0031-9007                     10.1103/PhysRevLett.122.132001
# 37  0031-9007  [10.1103/PhysRevLett.122.151802, 10.1103/PhysR...
# 38  2470-0010  [10.1103/PhysRevD.99.075009, 10.1103/PhysRevD....
# 39  0031-9007  [10.1103/PhysRevLett.122.132003, 10.1103/PhysR...
# 40  2470-0010  [10.1103/PhysRevD.99.075008, 10.1103/PhysRevD....
# 41  0031-9007  [10.1103/PhysRevLett.122.131803, 10.1103/PhysR...
# 42  0370-2693                     10.1016/j.physletb.2019.04.025
# 43  2470-0010  [10.1103/PhysRevD.98.095003, 10.1103/PhysRevD....
# 44  1029-8479  [10.1007/JHEP10(2018)188, 10.1007/JHEP10(2018)...
# 45  2470-0010  [10.1103/PhysRevD.99.015038, 10.1103/PhysRevD....
# 46  0031-9007  [10.1103/PhysRevLett.121.041802, 10.1103/PhysR...
# 47  0370-2693                     10.1016/j.physletb.2019.01.023
# 48  2470-0010  [10.1103/PhysRevD.98.055016, 10.1103/PhysRevD....
# 49  2470-0010  [10.1103/PhysRevD.97.115032, 10.1103/PhysRevD....
# 50  2470-0010  [10.1103/PhysRevD.98.103514, 10.1103/PhysRevD....
# 51  2470-0010                         10.1103/PhysRevD.97.095004
# 52  2470-0010  [10.1103/PhysRevD.98.015031, 10.1103/PhysRevD....
# 53  0217-751X  [10.1142/S0217751X18502068, 10.1142/S0217751X1...
# 54  2470-0010                         10.1103/PhysRevD.97.055045
# 55  2470-0010  [10.1103/PhysRevD.99.116007, 10.1103/PhysRevD....
# 56  0370-2693  [10.1016/j.physletb.2018.01.009, 10.1016/j.phy...
# 57  1029-8479                            10.1007/JHEP03(2018)167
# 59  0217-7323                          10.1142/S0217732318500244
# 60  0031-9007  [10.1103/PhysRevLett.120.142301, 10.1103/PhysR...

# %%
j='Phys.Lett.'
if not journal.get(j):print(1)
# Out:
# 1

# %%
        if not journal.get(j).get(container_title):
            try:
                ct=di.loc['container-title'][0]
                journal[j].update({container_title:ct})
            except:
                pass
        if not journal.get(j).get(issn):
            try:
                gis=di.loc['ISSN'].get('message')[0]
                journal[j].update({issn:gis})
            except:
                pass
# Out:
#                                                                   message  \
# DOI                                        10.1016/j.physletb.2020.135203
# ISSN                                                          [0370-2693]
# URL                      http://dx.doi.org/10.1016/j.physletb.2020.135203
# alternative-id                                        [S0370269320300071]
# article-number                                                     135203
# assertion               [{'name': 'publisher', 'value': 'Elsevier', 'l...
# author                  [{'family': 'Sirunyan', 'given': 'A.M.', 'affi...
# container-title                                       [Physics Letters B]
# content-domain          {'domain': ['elsevier.com', 'sciencedirect.com...
# created                 {'date-time': '2020-01-09T16:36:24Z', 'timesta...
# deposited               {'date-time': '2020-01-22T07:40:08Z', 'timesta...
# funder                  [{'award': [], 'name': 'Türkiye Atom Enerjisi ...
# indexed                 {'date-time': '2020-01-22T08:10:39Z', 'timesta...
# is-referenced-by-count                                                  0
# issn-type                       [{'type': 'print', 'value': '0370-2693'}]
# issued                                        {'date-parts': [[2020, 3]]}
# language                                                               en
# license                 [{'delay-in-days': 0, 'URL': 'https://www.else...
# link                    [{'content-type': 'text/xml', 'URL': 'https://...
# member                                                                 78
# original-title                                                         []
# page                                                               135203
# prefix                                                            10.1016
# published-print                               {'date-parts': [[2020, 3]]}
# publisher                                                     Elsevier BV
# reference-count                                                        48
# references-count                                                       48
# relation                                                               {}
# score                                                                   1
# short-container-title                                 [Physics Letters B]
# short-title                                                            []
# source                                                           Crossref
# subject                                 [Nuclear and High Energy Physics]
# subtitle                                                               []
# title                   [Observation of the Λb0→J/ψΛϕ decay in proton-...
# type                                                      journal-article
# update-policy                http://dx.doi.org/10.1016/elsevier_cm_policy
# volume                                                                802
#
#                        message-type message-version status
# DOI                            work           1.0.0     ok
# ISSN                           work           1.0.0     ok
# URL                            work           1.0.0     ok
# alternative-id                 work           1.0.0     ok
# article-number                 work           1.0.0     ok
# assertion                      work           1.0.0     ok
# author                         work           1.0.0     ok
# container-title                work           1.0.0     ok
# content-domain                 work           1.0.0     ok
# created                        work           1.0.0     ok
# deposited                      work           1.0.0     ok
# funder                         work           1.0.0     ok
# indexed                        work           1.0.0     ok
# is-referenced-by-count         work           1.0.0     ok
# issn-type                      work           1.0.0     ok
# issued                         work           1.0.0     ok
# language                       work           1.0.0     ok
# license                        work           1.0.0     ok
# link                           work           1.0.0     ok
# member                         work           1.0.0     ok
# original-title                 work           1.0.0     ok
# page                           work           1.0.0     ok
# prefix                         work           1.0.0     ok
# published-print                work           1.0.0     ok
# publisher                      work           1.0.0     ok
# reference-count                work           1.0.0     ok
# references-count               work           1.0.0     ok
# relation                       work           1.0.0     ok
# score                          work           1.0.0     ok
# short-container-title          work           1.0.0     ok
# short-title                    work           1.0.0     ok
# source                         work           1.0.0     ok
# subject                        work           1.0.0     ok
# subtitle                       work           1.0.0     ok
# title                          work           1.0.0     ok
# type                           work           1.0.0     ok
# update-policy                  work           1.0.0     ok
# volume                         work           1.0.0     ok

# %%
get_journal_info( {'publication_info':{'title':'B'}})

# %%
journal
# Out:
# {'A': {}, 'B': {}}

# %%
tmp.title
# Out:
# 0    {'title': 'Observation of the $\Lambda_\mathrm...
# Name: title, dtype: object

# %%
journal
# Out:
# {'Phys.Lett.': {}}

# %%
t=0.1
di=pd.read_json( 'https://api.crossref.org/works/{}'.format(doi) )
if not journal[j].get('container-title'):
    try:
        ct=di.loc['container-title'][0]
    except:
        ct=''
    journal[j]['container-title']=ct
if not journal[j].get('ISSN'):
    try:
        issn=di.loc['ISSN'].get('message')[0]
    except:
        issn=''
    journal[j]['ISSN']=issn
time.sleep=t

# %%
di
# Out:
#                                                                   message  \
# DOI                                        10.1016/j.physletb.2020.135203
# ISSN                                                          [0370-2693]
# URL                      http://dx.doi.org/10.1016/j.physletb.2020.135203
# alternative-id                                        [S0370269320300071]
# article-number                                                     135203
# assertion               [{'name': 'publisher', 'value': 'Elsevier', 'l...
# author                  [{'family': 'Sirunyan', 'given': 'A.M.', 'affi...
# container-title                                       [Physics Letters B]
# content-domain          {'domain': ['elsevier.com', 'sciencedirect.com...
# created                 {'date-time': '2020-01-09T16:36:24Z', 'timesta...
# deposited               {'date-time': '2020-01-22T07:40:08Z', 'timesta...
# funder                  [{'award': [], 'name': 'Türkiye Atom Enerjisi ...
# indexed                 {'date-time': '2020-01-22T08:10:39Z', 'timesta...
# is-referenced-by-count                                                  0
# issn-type                       [{'type': 'print', 'value': '0370-2693'}]
# issued                                        {'date-parts': [[2020, 3]]}
# language                                                               en
# license                 [{'delay-in-days': 0, 'URL': 'https://www.else...
# link                    [{'content-type': 'text/xml', 'URL': 'https://...
# member                                                                 78
# original-title                                                         []
# page                                                               135203
# prefix                                                            10.1016
# published-print                               {'date-parts': [[2020, 3]]}
# publisher                                                     Elsevier BV
# reference-count                                                        48
# references-count                                                       48
# relation                                                               {}
# score                                                                   1
# short-container-title                                 [Physics Letters B]
# short-title                                                            []
# source                                                           Crossref
# subject                                 [Nuclear and High Energy Physics]
# subtitle                                                               []
# title                   [Observation of the Λb0→J/ψΛϕ decay in proton-...
# type                                                      journal-article
# update-policy                http://dx.doi.org/10.1016/elsevier_cm_policy
# volume                                                                802
#
#                        message-type message-version status
# DOI                            work           1.0.0     ok
# ISSN                           work           1.0.0     ok
# URL                            work           1.0.0     ok
# alternative-id                 work           1.0.0     ok
# article-number                 work           1.0.0     ok
# assertion                      work           1.0.0     ok
# author                         work           1.0.0     ok
# container-title                work           1.0.0     ok
# content-domain                 work           1.0.0     ok
# created                        work           1.0.0     ok
# deposited                      work           1.0.0     ok
# funder                         work           1.0.0     ok
# indexed                        work           1.0.0     ok
# is-referenced-by-count         work           1.0.0     ok
# issn-type                      work           1.0.0     ok
# issued                         work           1.0.0     ok
# language                       work           1.0.0     ok
# license                        work           1.0.0     ok
# link                           work           1.0.0     ok
# member                         work           1.0.0     ok
# original-title                 work           1.0.0     ok
# page                           work           1.0.0     ok
# prefix                         work           1.0.0     ok
# published-print                work           1.0.0     ok
# publisher                      work           1.0.0     ok
# reference-count                work           1.0.0     ok
# references-count               work           1.0.0     ok
# relation                       work           1.0.0     ok
# score                          work           1.0.0     ok
# short-container-title          work           1.0.0     ok
# short-title                    work           1.0.0     ok
# source                         work           1.0.0     ok
# subject                        work           1.0.0     ok
# subtitle                       work           1.0.0     ok
# title                          work           1.0.0     ok
# type                           work           1.0.0     ok
# update-policy                  work           1.0.0     ok
# volume                         work           1.0.0     ok
